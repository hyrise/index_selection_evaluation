# %%
import pandas as pd

# %%
df = pd.read_csv('../tpch_with_cost_requests/combined_tpch_22_queries_new.csv', sep=';')

# %%
df['hit ratio'] = df['cache hits'] / df['cost requests']
df['effective calls'] = df['cost requests'] - df['cache hits']
df[['algorithm name', 'cost requests', 'cache hits', 'effective calls', 'hit ratio']]
# Out:
#     algorithm name  cost requests  cache hits  effective calls  hit ratio
# 0           dexter              0           0                0        NaN
# 1           dexter              0           0                0        NaN
# 2           dexter              0           0                0        NaN
# 3           dexter              0           0                0        NaN
# 4           dexter              0           0                0        NaN
# 5           dexter              0           0                0        NaN
# 6   drop_heuristic          31460       29955             1505   0.952161
# 7   drop_heuristic          31416       29916             1500   0.952254
# 8   drop_heuristic          31350       29858             1492   0.952408
# 9   drop_heuristic          31262       29780             1482   0.952594
# 10  drop_heuristic          31152       29672             1480   0.952491
# 11  drop_heuristic          31020       29541             1479   0.952321
# ...
